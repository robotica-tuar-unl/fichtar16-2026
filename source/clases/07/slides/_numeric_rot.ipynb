# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')

# %%
theta = np.deg2rad(30)
R_theta = np.array([
    [np.cos(theta), -np.sin(theta)],
    [np.sin(theta), np.cos(theta)]
])

print(R_theta)
# Out:
# [[ 0.8660254 -0.5      ]
#  [ 0.5        0.8660254]]

# %%
points = np.array([
    [2, 0],
    [2, 2],
    [1, 3],
    [0, 2],
    [0, 0],
    [2, 0],
])

# print(points)

# %%
p_rot = []
for p in points:
    p_rot.append(R_theta @ p)
points_rot = np.array(p_rot)

print(points_rot)
# Out:
# [[ 1.73205081  1.        ]
#  [ 0.73205081  2.73205081]
#  [-0.6339746   3.09807621]
#  [-1.          1.73205081]
#  [ 0.          0.        ]
#  [ 1.73205081  1.        ]]

# %%
#| label: rot-example-1
#| fig-cap: ""
#| fig-align: center

# Crear la figura y los ejes
fig, ax = plt.subplots()

ax.plot(points[0,0], points[0,1], marker='x', color='C0')
# ax.plot(points_rot[0,0], points_rot[0,1], marker='x', color='C1')

# Dibujar ejes en el centro
ax.spines['left'].set_visible(False)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_visible(False)
ax.spines['bottom'].set_position('zero')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Límites
ax.set_xlim(-2.5, 3.5)
ax.set_ylim(-2.5, 3.5)

# Ticks visibles pero sin etiquetas
ax.set_xticks(np.arange(-2, 4, 1))
ax.set_yticks(np.arange(-2, 4, 1))

# Cuadrículas
ax.minorticks_on()
ax.grid(True, which='major', linestyle='--', linewidth=0.5)
# ax.grid(True, which='minor', linestyle=':', linewidth=0.3)

ax.set_aspect('equal')
plt.show()

# %%
#| label: rot-example-2
#| fig-cap: ""
#| fig-align: center

# Crear la figura y los ejes
fig, ax = plt.subplots()

ax.plot(points[0,0], points[0,1], marker='x', color='C0')
ax.plot(points_rot[0,0], points_rot[0,1], marker='x', color='C1')

# Dibujar ejes en el centro
ax.spines['left'].set_visible(False)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_visible(False)
ax.spines['bottom'].set_position('zero')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Límites
ax.set_xlim(-2.5, 3.5)
ax.set_ylim(-2.5, 3.5)

# Ticks visibles pero sin etiquetas
ax.set_xticks(np.arange(-2, 4, 1))
ax.set_yticks(np.arange(-2, 4, 1))

# Cuadrículas
ax.minorticks_on()
ax.grid(True, which='major', linestyle='--', linewidth=0.5)
# ax.grid(True, which='minor', linestyle=':', linewidth=0.3)

ax.set_aspect('equal')
plt.show()

# %%
#| label: rot-example-3
#| fig-cap: ""
#| fig-align: center

# Crear la figura y los ejes
fig, ax = plt.subplots()

ax.plot(points[:2,0], points[:2,1], marker='x', color='C0')
ax.plot(points_rot[0,0], points_rot[0,1], marker='x', color='C1')

# Dibujar ejes en el centro
ax.spines['left'].set_visible(False)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_visible(False)
ax.spines['bottom'].set_position('zero')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Límites
ax.set_xlim(-2.5, 3.5)
ax.set_ylim(-2.5, 3.5)

# Ticks visibles pero sin etiquetas
ax.set_xticks(np.arange(-2, 4, 1))
ax.set_yticks(np.arange(-2, 4, 1))

# Cuadrículas
ax.minorticks_on()
ax.grid(True, which='major', linestyle='--', linewidth=0.5)
# ax.grid(True, which='minor', linestyle=':', linewidth=0.3)

ax.set_aspect('equal')
plt.show()

# %%
#| label: rot-example-4
#| fig-cap: ""
#| fig-align: center

# Crear la figura y los ejes
fig, ax = plt.subplots()

ax.plot(points[:2,0], points[:2,1], marker='x', color='C0')
ax.plot(points_rot[:2,0], points_rot[:2,1], marker='x', color='C1')

# Dibujar ejes en el centro
ax.spines['left'].set_visible(False)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_visible(False)
ax.spines['bottom'].set_position('zero')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Límites
ax.set_xlim(-2.5, 3.5)
ax.set_ylim(-2.5, 3.5)

# Ticks visibles pero sin etiquetas
ax.set_xticks(np.arange(-2, 4, 1))
ax.set_yticks(np.arange(-2, 4, 1))

# Cuadrículas
ax.minorticks_on()
ax.grid(True, which='major', linestyle='--', linewidth=0.5)
# ax.grid(True, which='minor', linestyle=':', linewidth=0.3)

ax.set_aspect('equal')
plt.show()

# %%
#| label: rot-example-5
#| fig-cap: ""
#| fig-align: center

# Crear la figura y los ejes
fig, ax = plt.subplots()

ax.plot(points[:,0], points[:,1], marker='x', color='C0')
ax.plot(points_rot[:,0], points_rot[:,1], marker='x', color='C1')

# Dibujar ejes en el centro
ax.spines['left'].set_visible(False)
ax.spines['left'].set_position('zero')
ax.spines['bottom'].set_visible(False)
ax.spines['bottom'].set_position('zero')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Límites
ax.set_xlim(-2.5, 3.5)
ax.set_ylim(-2.5, 3.5)

# Ticks visibles pero sin etiquetas
ax.set_xticks(np.arange(-2, 4, 1))
ax.set_yticks(np.arange(-2, 4, 1))

# Cuadrículas
ax.minorticks_on()
ax.grid(True, which='major', linestyle='--', linewidth=0.5)
# ax.grid(True, which='minor', linestyle=':', linewidth=0.3)

ax.set_aspect('equal')
plt.show()
